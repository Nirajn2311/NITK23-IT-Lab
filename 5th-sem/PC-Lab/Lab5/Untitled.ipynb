# %%
import matplotlib.pyplot as plt

# %%
x = [5000,10000,50000,100000,500000]

# %%
y_seq = [0.000762,0.000828,0.001100,0.001532,0.003587]
y_st = [0.001229,0.001216,0.001288,0.001376,0.001877]
y_st_ch = [0.001360,0.001318,0.001381,0.001496,0.001791]
y_dy = [0.001390,0.001418,0.001628,0.001732,0.001797]
y_gui = [0.000757,0.001220,0.001438,0.001280,0.001349]
y_run = [0.001468,0.001640,0.005310,0.010508,0.037395]

# %%
plt.figure(figsize=(15,8))
plt.plot(x, y_seq, label='Sequential')
plt.plot(x, y_st, label='Static')
plt.plot(x, y_st_ch, label='Static, 10')
plt.plot(x, y_dy, label='Dynamic, 10')
plt.plot(x, y_gui, label='Guided, 10')
plt.plot(x, y_run, label='Runtime')
plt.legend()
plt.grid()
plt.xticks(x)
plt.xlabel("No. of Iterations")
plt.ylabel("Time (s)")
plt.show()
